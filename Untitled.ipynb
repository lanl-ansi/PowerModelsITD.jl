# %%
using PowerModelsDistribution

# %%
nw = parse_file("/Users/rferrando/Desktop/opfitd_restore_CA+123/data/distribution/123Bus/IEEE123Master.dss", multinetwork=true)
# Out:
# [ PowerModelsDistribution | Info ] : Circuit has been reset with the 'clear' on line 8 in 'IEEE123Master.dss'
# [ PowerModelsDistribution | Info ] : Redirecting to 'ieeelinecodes.dss' on line 31 in 'IEEE123Master.dss'
# [ PowerModelsDistribution | Info ] : Redirecting to 'ieee123regulators.dss' on line 207 in 'IEEELineCodes.dss'
# [ PowerModelsDistribution | Info ] : Redirecting to 'ieee123loads.dss' on line 211 in 'IEEE123Regulators.dss'
# [ PowerModelsDistribution | Info ] : Command 'calcvoltagebases' on line 221 in 'IEEE123Master.dss' is not supported, skipping.
# [ PowerModelsDistribution | Info ] : basemva=100 is the default value, you may want to adjust sbase_default for better convergence
# [ PowerModelsDistribution | Info ] : assuming time is in hours for time_elapsed inference. if this is incorrect, manually adjust with set_time_elapsed!
# Dict{String, Any} with 6 entries:
#   "name"         => "ieee123"
# ...

# %%
nw_math = transform_data_model(nw)
# Out:
# Dict{String, Any} with 6 entries:
#   "name"         => "ieee123"
#   "map"          => Dict{String, Vector{Dict{String, Any}}}("1"=>[Dict("unmap_f…
#   "bus_lookup"   => Dict{String, Dict{String, Any}}("1"=>Dict("32"=>1, "29"=>2,…
#   "multinetwork" => true
#   "nw"           => Dict{String, Any}("1"=>Dict{String, Any}("is_kron_reduced"=…
#   "data_model"   => MATHEMATICAL

# %%
nw_math["nw"]["1"]["load"]["1"]
# Out:
# Dict{String, Any} with 13 entries:
#   "model"         => IMPEDANCE
#   "connections"   => [1]
#   "configuration" => WYE
#   "name"          => "s11a"
#   "status"        => 1
#   "qd"            => [0.00017]
#   "vbase"         => 2.40178
#   "vnom_kv"       => 0.99926
#   "source_id"     => "load.s11a"
#   "load_bus"      => 99
#   "dispatchable"  => 0
#   "index"         => 1
#   "pd"            => [0.00034]
